# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sqlalchemy import MetaData
import numpy as np
import pandas as pd
import csv
from collections import defaultdict
import re
import statsmodels.api as sm
from patsy import dmatrices
from sklearn.cross_validation import train_test_split
from __future__ import division
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
import seaborn as sns
from sqlalchemy import MetaData
from sqlalchemy import create_engine
from sqlalchemy.engine.url import URL
import settings
import time
import glob

# %%
def db_connect():
    """
    Performs database connection using database settings from settings.py.
    Returns sqlalchemy engine instance
    """
    return create_engine(URL(**settings.DATABASE))

db = db_connect()
db
# Out:
# Engine(postgres://mimic:***@metis.cabju7mub8cg.us-west-2.rds.amazonaws.com:5432/MIMIC_ICU)

# %%
# Get list of all tables in db
m = MetaData(bind=db)
m.reflect()
tables = list(m.tables.keys())
tables
# Out:
# [u'd_cpt',
#  u'w_chartevents_1',
#  u'diagnoses_icd',
#  u'labevents',
#  u'transfers',
#  u'chartevents',
#  u'pokemon',
#  u'icustays',
#  u'd_labitems',
#  u'microbiologyevents',
#  u'procedures_icd',
#  u'datetimeevents',
#  u'prescriptions',
#  u'callout',
#  u'drgcodes',
#  u'noteevents',
#  u'chartevents_14',
#  u'chartevents_13',
#  u'chartevents_12',
#  u'chartevents_11',
#  u'chartevents_10',
#  u'chartevents_9',
#  u'chartevents_8',
#  u'chartevents_7',
#  u'chartevents_6',
#  u'chartevents_5',
#  u'chartevents_4',
#  u'chartevents_3',
#  u'chartevents_2',
#  u'chartevents_1',
#  u'caregivers',
#  u'admissions',
#  u'w_chartevents_6',
#  u'w_chartevents_5',
#  u'w_chartevents_4',
#  u'w_chartevents_3',
#  u'w_chartevents_2',
#  u'd_items',
#  u'services',
#  u'inputevents_mv',
#  u'd_icd_procedures',
#  u'w_chartevents_8',
#  u'procedureevents_mv',
#  u'w_chartevents_7',
#  u'w_chartevents_13',
#  u'w_chartevents_12',
#  u'w_chartevents_11',
#  u'w_chartevents_10',
#  u'w_chartevents_14',
#  u'w_chartevents_9',
#  u'patients',
#  u'inputevents_cv',
#  u'team_mcnulty_five',
#  u'outputevents',
#  u'd_icd_diagnoses',
#  u'cptevents']

# %% [markdown]
# # Select ITEM IDs, count per patient and map by ITEMs' cluster

# %%
# from list of tables, get all chartevent tables
tab_re = re.compile(r'(chartevents.*)')
chart_tables = []
for table in tables:
    name = re.findall(tab_re, table)
    if name:
        chart_tables.append(name[0])
chart_tables = sorted(chart_tables)
chart_tables
# Out:
# [u'chartevents',
#  u'chartevents_1',
#  u'chartevents_10',
#  u'chartevents_11',
#  u'chartevents_12',
#  u'chartevents_13',
#  u'chartevents_14',
#  u'chartevents_2',
#  u'chartevents_3',
#  u'chartevents_4',
#  u'chartevents_5',
#  u'chartevents_6',
#  u'chartevents_7',
#  u'chartevents_8',
#  u'chartevents_9']

# %%
# Query itemid + distinct number of patients that itemid has been applied to
# save the query result in a csv file 
for chart in chart_tables:
    filename = chart + '.csv'
    start = time.time()
    que = '''select itemid, count(distinct subject_id) as num_patients
            from %s 
            group by itemid ''' % chart
    df = pd.read_sql(que, db)
    df.to_csv(filename)
    print(chart)
    print(time.time()-start)
    df = None

# %%
# read all the csv files from the psql query, concat into a df

filenames=glob.glob('chartevents_*')
dflist=[]
for filename in filenames:
    df = pd.read_csv(filename, index_col = 0)
    dflist.append(df)

chart_df = pd.concat(dflist)

# %%
# Reading in file with ITEM_ID | NUM_OF_PATIENTS w item id
# Start here to skip all past steps
chart_df = pd.read_csv('chartevents.csv')

# %% [markdown]
# # START MAPPING ITEMS

# %%
# pull the d_items database (prepping to join to chart_df)
query = '''select * from d_items'''
d_items_df = pd.read_sql(query, db)
d_items_df.head(2)
# Out:
#    row_id  itemid                 label abbreviation dbsource      linksto  \
# 0     262     264  INV Line#7 Site Date               carevue  chartevents
# 1     263     265     INV Line#7 [Type]               carevue  chartevents
#
#   category unitname param_type conceptid
# 0                                   None
# 1                                   None

# %%
# Joining the df, get the labes of items
feat_df = chart_df.merge(d_items_df[['itemid', 'label']], on='itemid')
feat_df.sort_values(by='num_patients', ascending = False).head(50)
feat_df.head(2)
# Out:
#    Unnamed: 0  itemid  num_patients              label_x     ratio  \
# 0        1184     813         10777           Hematocrit  1.000000
# 1        1200     829         10776  Potassium (3.5-5.3)  0.999907
#
#                label_y
# 0           Hematocrit
# 1  Potassium (3.5-5.3)

# %%
feat_df['PatFracts'] = feat_df.num_patients / 18000

# %%
feat_df = feat_df.sort_values(by='PatFracts', ascending = False)
feat_df.head(10)
# Out:
#    Unnamed: 0  itemid  num_patients              label_x     ratio  \
# 0        1184     813         10777           Hematocrit  1.000000
# 1        1200     829         10776  Potassium (3.5-5.3)  0.999907
# 2        1227     861         10774       WBC (4-11,000)  0.999722
# 3        1207     837         10774     Sodium (135-148)  0.999722
# 4        1153     781         10774           BUN (6-20)  0.999722
# 5        1182     811         10774     Glucose (70-105)  0.999722
# 6        1199     828         10773            Platelets  0.999629
# 7        1160     788         10773   Chloride (100-112)  0.999629
# 8        1162     791         10773   Creatinine (0-1.3)  0.999629
# 9        1185     814         10772           Hemoglobin  0.999536
#
#                label_y  PatFracts
# 0           Hematocrit   0.598722
# 1  Potassium (3.5-5.3)   0.598667
# 2       WBC (4-11,000)   0.598556
# 3     Sodium (135-148)   0.598556
# 4           BUN (6-20)   0.598556
# 5     Glucose (70-105)   0.598556
# 6            Platelets   0.598500
# 7   Chloride (100-112)   0.598500
# 8   Creatinine (0-1.3)   0.598500
# 9           Hemoglobin   0.598444

# %% [markdown]
# ## Combine ITEMS by cluster

# %%
items_dict = defaultdict(list)

file = open('item_matching.txt', 'r')
reader = csv.reader(file)
ITEMS = list(reader)
for item in ITEMS:
    for i in item[:-1]:
        items_dict[i] = item[-1]
file.close()

# %%
mapped_label = []
for row in feat_df.iterrows():
    mapped_label.append(items_dict.get(str(row[1]['itemid']), np.nan))
    if pd.isnull(mapped_label[-1]):
        mapped_label[-1] = row[1]['label_x'].lower()
    else:
        mapped_label[-1] = mapped_label[-1].upper()
feat_df['ItemMap'] = mapped_label

# %%
feat_df.head(100)
# Out:
#     Unnamed: 0  itemid  num_patients               label_x     ratio  \
# 0         1184     813         10777            Hematocrit  1.000000
# 1         1200     829         10776   Potassium (3.5-5.3)  0.999907
# 2         1227     861         10774        WBC (4-11,000)  0.999722
# 3         1207     837         10774      Sodium (135-148)  0.999722
# 4         1153     781         10774            BUN (6-20)  0.999722
# 5         1182     811         10774      Glucose (70-105)  0.999722
# 6         1199     828         10773             Platelets  0.999629
# 7         1160     788         10773    Chloride (100-112)  0.999629
# 8         1162     791         10773    Creatinine (0-1.3)  0.999629
# 9         1185     814         10772            Hemoglobin  0.999536
# 10        1203     833         10771                   RBC  0.999443
# 11        1159     787         10768        Carbon Dioxide  0.999165
# 12        1192     821         10750   Magnesium (1.6-2.6)  0.997495
# 13        1701     646         10621                  SpO2  0.985525
# 14        1138     742         10619            calprevflg  0.985339
# 15        3402     212         10619          Heart Rhythm  0.985339
# 16           4     618         10619      Respiratory Rate  0.985339
# 17        3401     211         10619            Heart Rate  0.985339
# 18        2419     161         10618           Ectopy Type  0.985246
# 25        2611     454         10617        Motor Response  0.985154
# 30           3     617         10617   Respiratory Pattern  0.985154
# 29        2585     425         10617       LLL Lung Sounds  0.985154
# 28        2588     428         10617       LUL Lung Sounds  0.985154
# 27        2592     432         10617    Level of Conscious  0.985154
# 26        1773     723         10617       Verbal Response  0.985154
# 24        2441     184         10617           Eye Opening  0.985154
# 23        2748     599         10617       RUL Lung Sounds  0.985154
# 22        2742     593         10617       RLL Lung Sounds  0.985154
# 21        2455     198         10617             GCS Total  0.985154
# 20        2296      27         10617  Abdominal Assessment  0.985154
# ..         ...     ...           ...                   ...       ...
# 70        1139     762         10352              Admit Wt  0.960564
# 71        1230     919         10352               Service  0.960564
# 72        1228     916         10352             Allergy 1  0.960564
# 73        1237     935         10352             Allergy 3  0.960564
# 74        1236     930         10352                   Ext  0.960564
# 75        1235     927         10352             Allergy 2  0.960564
# 76        1234     926         10352              Religion  0.960564
# 77        1233     925         10352        Marital Status  0.960564
# 78        1232     924         10352           Readmission  0.960564
# 79        1231     920         10352              Admit Ht  0.960564
# 80        1229     917         10351          Diagnosis/op  0.960471
# 81        2340      77         10347              Behavior  0.960100
# 82        1186     815         10322  INR (2-4 ref. range)  0.957780
# 83        1196     825         10320            PTT(22-35)  0.957595
# 84        1195     824         10314           PT(11-13.5)  0.957038
# 85        1322    1127         10245      WBC   (4-11,000)  0.950636
# 86        2444     187         10224  Family Communication  0.948687
# 87        2624     467         10033    O2 Delivery Device  0.930964
# 88        2487     294          9985          IV #1 [Site]  0.926510
# 89        1320    1125          9943          Service Type  0.922613
# 90        2495     324          9936     IV Site Appear #1  0.921963
# 91           7     621          9838    Restraint Location  0.912870
# 92        1292    1087          9757    Pain Assess Method  0.905354
# 93         122    8400          9704          IV #1 [Size]  0.900436
# 94        2731     582          9610            Procedures  0.891714
# 95        2337      72          9606             Back Care  0.891343
# 96        2627     470          9580         O2 Flow (lpm)  0.888930
# 97        2632     477          9555             Oral Care  0.886610
# 98        1697     642          9498             Skin Care  0.881321
# 99        2412     154          9470             Diet Type  0.878723
#
#                  label_y  PatFracts               ItemMap
# 0             Hematocrit   0.598722            hematocrit
# 1    Potassium (3.5-5.3)   0.598667   potassium (3.5-5.3)
# 2         WBC (4-11,000)   0.598556        wbc (4-11,000)
# 3       Sodium (135-148)   0.598556      sodium (135-148)
# 4             BUN (6-20)   0.598556            bun (6-20)
# 5       Glucose (70-105)   0.598556               GLUCOSE
# 6              Platelets   0.598500             platelets
# 7     Chloride (100-112)   0.598500    chloride (100-112)
# 8     Creatinine (0-1.3)   0.598500    creatinine (0-1.3)
# 9             Hemoglobin   0.598444            hemoglobin
# 10                   RBC   0.598389                   rbc
# 11        Carbon Dioxide   0.598222        carbon dioxide
# 12   Magnesium (1.6-2.6)   0.597222   magnesium (1.6-2.6)
# 13                  SpO2   0.590056                  SPO2
# 14            calprevflg   0.589944            calprevflg
# 15          Heart Rhythm   0.589944          heart rhythm
# 16      Respiratory Rate   0.589944              RESPRATE
# 17            Heart Rate   0.589944             HEARTRATE
# 18           Ectopy Type   0.589889           ectopy type
# 25        Motor Response   0.589833              GCSMOTOR
# 30   Respiratory Pattern   0.589833   respiratory pattern
# 29       LLL Lung Sounds   0.589833       lll lung sounds
# 28       LUL Lung Sounds   0.589833       lul lung sounds
# 27    Level of Conscious   0.589833    level of conscious
# 26       Verbal Response   0.589833             GCSVERBAL
# 24           Eye Opening   0.589833               GCSEYES
# 23       RUL Lung Sounds   0.589833       rul lung sounds
# 22       RLL Lung Sounds   0.589833       rll lung sounds
# 21             GCS Total   0.589833             gcs total
# 20  Abdominal Assessment   0.589833  abdominal assessment
# ..                   ...        ...                   ...
# 70              Admit Wt   0.575111              admit wt
# 71               Service   0.575111               service
# 72             Allergy 1   0.575111             allergy 1
# 73             Allergy 3   0.575111             allergy 3
# 74                   Ext   0.575111                   ext
# 75             Allergy 2   0.575111             allergy 2
# 76              Religion   0.575111              religion
# 77        Marital Status   0.575111        marital status
# 78           Readmission   0.575111           readmission
# 79              Admit Ht   0.575111              admit ht
# 80          Diagnosis/op   0.575056          diagnosis/op
# 81              Behavior   0.574833              behavior
# 82  INR (2-4 ref. range)   0.573444  inr (2-4 ref. range)
# 83            PTT(22-35)   0.573333            ptt(22-35)
# 84           PT(11-13.5)   0.573000           pt(11-13.5)
# 85      WBC   (4-11,000)   0.569167      wbc   (4-11,000)
# 86  Family Communication   0.568000  family communication
# 87    O2 Delivery Device   0.557389      O2FROMVENTILATOR
# 88          IV #1 [Site]   0.554722          iv #1 [site]
# 89          Service Type   0.552389          service type
# 90     IV Site Appear #1   0.552000     iv site appear #1
# 91    Restraint Location   0.546556    restraint location
# 92    Pain Assess Method   0.542056    pain assess method
# 93          IV #1 [Size]   0.539111          iv #1 [size]
# 94            Procedures   0.533889            procedures
# 95             Back Care   0.533667             back care
# 96         O2 Flow (lpm)   0.532222                O2FLOW
# 97             Oral Care   0.530833             oral care
# 98             Skin Care   0.527667             skin care
# 99             Diet Type   0.526111             diet type
#
# [100 rows x 8 columns]

# %%
# Make a new ItemMap column
feat_df['ItemMap'] = [items_dict.get(str(x), np.nan) for x in feat_df['itemid']]

# %%
sum(feat_df.PatFracts>0.1)
# Out:
# 581

# %%
# Make a new ItemMap column 
[items_dict.get(str(x), np.nan) for x in feat_df[['itemid','label_x']]]
# Out:
# [nan, nan]
